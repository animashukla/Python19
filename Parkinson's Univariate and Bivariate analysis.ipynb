# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
import seaborn as sns

# %%
df=pd.read_csv("Ensemble_Project_Parkinson's.csv")

# %%
df['MDVP:Fo(Hz)'].hist()

# %%
plt.boxplot(df['MDVP:Fhi(Hz)'])
#From the boxplot we see that there are outliers but not distinct. the values are just away from the normal range
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb1d1ec8>,
#   <matplotlib.lines.Line2D at 0xb1d1fc8>],
#  'caps': [<matplotlib.lines.Line2D at 0xb1d4b08>,
#   <matplotlib.lines.Line2D at 0xb1d5988>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb1d1688>],
#  'medians': [<matplotlib.lines.Line2D at 0xb1d5a88>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb1dd848>],
#  'means': []}

# %%
df['MDVP:Fhi(Hz)'].hist()

# %%
plt.boxplot(df['MDVP:Flo(Hz)'])
#the box plot given for minimum fundamental vocal frequency sees a few outliers but are not as distict that can be dropped.
#the same can be justified using a hist plot. the distribution is not symmetric/normal but no such values that can be dropped
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb4f1c08>,
#   <matplotlib.lines.Line2D at 0xb4f1d08>],
#  'caps': [<matplotlib.lines.Line2D at 0xb4f7848>,
#   <matplotlib.lines.Line2D at 0xb4f7d08>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb4f13c8>],
#  'medians': [<matplotlib.lines.Line2D at 0xb4f7e08>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb4fd808>],
#  'means': []}

# %%
df['MDVP:Flo(Hz)'].hist()

# %%
plt.boxplot(df['MDVP:Jitter(%)'])
#We can clearly see outliers in case of jitter percentage. For performing operations, we shall require to take the median 
#and replace outliers with median where the percentage is more than a given 0.020
#same can e be justified using a hist plot
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb5579c8>,
#   <matplotlib.lines.Line2D at 0xb557f48>],
#  'caps': [<matplotlib.lines.Line2D at 0xb557ec8>,
#   <matplotlib.lines.Line2D at 0xb55c9c8>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb54efc8>],
#  'medians': [<matplotlib.lines.Line2D at 0xb55cf48>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb55cec8>],
#  'means': []}

# %%
df['MDVP:Jitter(%)'].hist()

# %%
plt.boxplot(df['MDVP:Jitter(Abs)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb5bbe88>,
#   <matplotlib.lines.Line2D at 0xb5bbf88>],
#  'caps': [<matplotlib.lines.Line2D at 0xb5c09c8>,
#   <matplotlib.lines.Line2D at 0xb5c0f08>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb5bb708>],
#  'medians': [<matplotlib.lines.Line2D at 0xb5c0e88>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb5c5a08>],
#  'means': []}

# %%
df['MDVP:Jitter(Abs)'].hist()

# %% [markdown]
# #After analysing the box plot and hist plot, we can find that most of the absolute value is concentrated till 0.00015. And has outliers from 0.00020 to 0.00025. These values maybe required to be replaced by the median of the column

# %%
#plt.boxplot(df['MDVP:RAP'])

# %%
df['MDVP:RAP'].hist()
#outlier range is very minimal so that can be either replaced with median or can be kept as it is as showing no impact

# %%
plt.boxplot(df['MDVP:PPQ'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x550ff48>,
#   <matplotlib.lines.Line2D at 0x550fec8>],
#  'caps': [<matplotlib.lines.Line2D at 0x5512a88>,
#   <matplotlib.lines.Line2D at 0x5512fc8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x550f6c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x5512f48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x5517b48>],
#  'means': []}

# %%
df['MDVP:PPQ'].hist()
#the outliers can be seen nearly before 0.015 till 0.020

# %%
#plt.boxplot(df['Jitter:DDP'])

# %%
df['Jitter:DDP'].hist()
#we can see a distinctive values nearly from 0.05 to 0.06 and bit above. these values might be required to be arranged for mathematical ease

# %%
#plt.boxplot(df['MDVP:Shimmer'])
df['MDVP:Shimmer'].hist()
# the Shimmer value is mostly concentrated from 0.02 to 0.08. we can see one set of values outlying near to point 0.12

# %%
df['MDVP:Shimmer(dB)'].hist()
#the Shimmer(db) value is mostly concentrated from 0.2 to 1.0. we can see one set of values outlying near to point 1.2. 
#this value does not require any amendment. We can take this in concern while performing statisctical analysis

# %%
#plt.boxplot(df['Shimmer:APQ3'])
df['Shimmer:APQ3'].hist()
#

# %%
plt.boxplot(df['Shimmer:APQ5'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb732a88>,
#   <matplotlib.lines.Line2D at 0xb732fc8>],
#  'caps': [<matplotlib.lines.Line2D at 0xb732f88>,
#   <matplotlib.lines.Line2D at 0xb737b08>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb732208>],
#  'medians': [<matplotlib.lines.Line2D at 0xb737f48>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb737fc8>],
#  'means': []}

# %%
df['Shimmer:APQ5'].hist()

# %%
plt.boxplot(df['MDVP:APQ'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb79ab88>,
#   <matplotlib.lines.Line2D at 0xb79afc8>],
#  'caps': [<matplotlib.lines.Line2D at 0xb79f6c8>,
#   <matplotlib.lines.Line2D at 0xb79fc08>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb79a348>],
#  'medians': [<matplotlib.lines.Line2D at 0xb79fd08>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb7a6708>],
#  'means': []}

# %%
df['MDVP:APQ'].hist()
#the box plot and hist plot both conclude that there is an extreme outlier between 0.12 and 0.14. This outlier can be replaced
#by the median of Amplitude Perturbation Quotient

# %%
#plt.boxplot(df['Shimmer:DDA'])
df['Shimmer:DDA'].hist()
#one outlieer can be seen between 0.14 to 0.18, if the same has very significant existance, it should be replaced by its median
#Additionally, the curve is symmetric at the right hand.

# %%
plt.boxplot(df['NHR'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb867648>,
#   <matplotlib.lines.Line2D at 0xb867bc8>],
#  'caps': [<matplotlib.lines.Line2D at 0xb867cc8>,
#   <matplotlib.lines.Line2D at 0xb86d6c8>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb861e08>],
#  'medians': [<matplotlib.lines.Line2D at 0xb86dc48>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb86dd48>],
#  'means': []}

# %%
df['NHR'].hist()
#from box plot and histogram, we have quite a number of outliers and the distribution of the curve is not symmetric on either side

# %%
#plt.boxplot(df['HNR'])
df['HNR'].hist()
#the histogram shows that there are no out liers and despite the curve not being very symmetric on either sides

# %%
#plt.boxplot(df['RPDE'])
df['RPDE'].hist()
#there are no outliers. But not a perfect symmetry can be seen in this column

# %%
#plt.boxplot(df['DFA'])
df['DFA'].hist()
#there are no outliers. But not a perfect symmetry can be seen in this column

# %%
#plt.boxplot(df['spread1'])
df['spread1'].hist()
#there are no outliers. But not a perfect symmetry can be seen in this column

# %%
#plt.boxplot(df['spread2'])
df['spread2'].hist()
#there are no outliers. But not a perfect symmetry can be seen in this column

# %%
#plt.boxplot(df['D2'])
df['D2'].hist()
#there are no outliers. But not a perfect symmetry can be seen in this column

# %%
#plt.boxplot(df['PPE'])
df['PPE'].hist()
#there are no outliers. But not a perfect symmetry can be seen in this column
